# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
html=req.get(url).content 
html
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n\n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-719f1193e0c0.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-0c343b529849.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_dimmed-f22da508b62a.css" /><link data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-188ef1de59e6.css" /><link data-color-theme="dark_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_colorblind-bc6bf4eea850.css" /><link data-color-theme="light_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-527658dec362.css" /><link data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-c7a7fe0cd8ec.css" /><link data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-6aa855bdae0f.css" /><link data-color-theme="dark_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_tritanopia-6aa5e25aacc0.css" />\n  \n  \n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-3e0c23f0f191.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/global-97a341ceda9f.css" />\n    <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/github-2bd0741c348f.css" />\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/site-a015b1c08678.css" />\n<link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/explore-7cbc4c438037.css" />\n\n\n\n  <script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/wp-runtime-253f26d9a617.js"></script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_smoothscroll-polyfill_dist_smoothscroll_js-node_modules_stacktrace-parse-297da6-612147423330.js"></script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/environment-056aee03b442.js"></script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_selector-observer_dist_index_esm_js-2646a2c533e3.js"></script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_delegated-events_dist_index_js-node_modules_github_details-dialog-elemen-63debe-c04540d458d4.js"></script>\n<script crossorigin="anonymous" defer="defer" type="application/javascript" src="https://github.githubassets ...

# %%
len(html)
# Out:
# 441138

# %%
soup=bs(html, 'html.parser')

# %%
len(soup.find_all('table'))
# Out:
# 0

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
git_name = soup.find_all('h1',class_='h3 lh-condensed')

git_name[0].text.strip()
# Out:
# 'Ariel Mashraki'

# %%
names = []
for element in git_name:
    name = element.text
    name = name.strip().replace("\n", "")
    names.append(name)

print(names)
# Out:
# ['Ariel Mashraki', 'Mattias Wadman', 'Henrik Rydgård', 'Mark Tyneway', 'Lincoln Stein', 'jxxghp', 'Paul Razvan Berg', 'Florian Roth', 'MichaIng', 'Vectorized', 'Lianmin Zheng', 'X.', 'Norbert de Langen', 'Stefan Prodan', 'Jaco', 'François Chollet', 'Michał Lytek', 'Lukas Taegert-Atkinson', 'Ben McCann', 'Antonio Cheong', 'Maarten Grootendorst', 'Leon', 'syuilo', 'Abhinav Gupta', 'Yair Morgenstern']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
python = req.get(url).content 
soup = bs(python, 'html.parser')
python_names = soup.find_all('h1',class_='h3 lh-condensed')

# %%
names = []
for element in python_names:
    name = element.text
    name = name.strip().replace("\n", "").replace(" ", "")
    names.append(name)

print(names)
# Out:
# ['acheong08/ChatGPT', 'Zero6992/chatGPT-discord-bot', 'TheAlgorithms/Python', 'LAION-AI/Open-Assistant', 'ddPn08/Lsmith', 'zhayujie/chatgpt-on-wechat', 'LeagueOfPoro/CapsuleFarmerEvolved', 'microsoft/BioGPT', 'BlinkDL/ChatRWKV', 'AIGCT/EASYChatGPT', 'mmz-001/knowledge_gpt', 'jxxghp/nas-tools', 'tiangolo/fastapi', 'TomSchimansky/CustomTkinter', 'Rudrabha/Wav2Lip', 'public-apis/public-apis', 'biancangming/wtv', 'chidiwilliams/buzz', 'bellingcat/octosuite', 'approximatelabs/sketch', 'yerfor/GeneFace', 'uptrain-ai/uptrain', 'facebookresearch/metaseq', 'lss233/chatgpt-mirai-qq-bot', 'ansible/ansible']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
wd = req.get(url).content
soup = bs(wd, 'html.parser')

# %%
wd_image = soup.find_all('img')
wd_image[0]
# Out:
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/icons/wikipedia.png" width="50"/>

# %%
wd_images_lst = []
for i in wd_image:
    wd_images_lst.append(i.get('src'))
wd_images_lst
# Out:
# ['/static/images/icons/wikipedia.png',
#  '/static/images/mobile/copyright/wikipedia-wordmark-en.svg',
#  '/static/images/mobile/copyright/wikipedia-tagline-en.svg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg/220px-Walt_Disney_Snow_white_1937_trailer_screenshot_%2813%29.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/15/Disney_drawing_goofy.jpg/170px-Disney_drawing_goofy.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/WaltDisneyplansDisneylandDec1954.jpg/220px-WaltDisneyplansDisneylandDec1954.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Walt_disney_portrait_right.jpg/170px-Walt_disney_portrait_right.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Walt_Disney_Grave.JPG/170px-Walt_Disney_Grave.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Roy_O._Disney_with_Company_at_Press_Conference.jpg/170px-Roy_O._Disney_with_Company_at_Press_Conference.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/13/DisneySchiphol1951.jpg/220px-DisneySchiphol1951.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Disney1968.jpg/170px-Disney1968.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Disney_Oscar_1953_%28cropped%29.jpg/170px-Disney_Oscar_1953_%28cropped%29.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/30px-Commons-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/38px-Wikisource-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/34px-Wikiquote-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Disneyland_Resort_logo.svg/135px-Disneyland_Resort_logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/da/Animation_disc.svg/20px-Animation_disc.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/6/69/P_vip.svg/19px-P_vip.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Magic_Kingdom_castle.jpg/15px-Magic_Kingdom_castle.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Video-x-generic.svg/19px-Video-x-generic.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Flag_of_Los_Angeles_County%2C_California.svg/21px-Flag_of_Los_Angeles_County%2C_California.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/8c/Blank_television_set.svg/21px-Blank_television_set.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/21px-Flag_of_the_United_States.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4a/Commons-logo.svg/14px-Commons-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Wikiquote-logo.svg/16px-Wikiquote-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/18px-Wikisource-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/f/ff/Wikidata-logo.svg/21px-Wikidata-logo.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/10px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#  '//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1',
#  '/static/images/footer/wikimedia-button.png',
#  '/static/images/footer/poweredby_mediawiki_88x31.png']

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python'

# %%
py = req.get(url).content
soup = bs(py, 'html.parser')

# %%
py_l= soup.find_all('a')
py_l[0]
# Out:
# <a class="mw-jump-link" href="#bodyContent">Jump to content</a>

# %%
py_link = []
for i in py_l:
    py_link.append(i.get('href'))
py_link
# Out:
# ['#bodyContent',
#  '/wiki/Main_Page',
#  '/wiki/Special:Search',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:CreateAccount&returnto=Python',
#  '/w/index.php?title=Special:UserLogin&returnto=Python',
#  '/wiki/Help:Introduction',
#  '/wiki/Special:MyTalk',
#  '/wiki/Special:MyContributions',
#  '/wiki/Main_Page',
#  '/wiki/Wikipedia:Contents',
#  '/wiki/Portal:Current_events',
#  '/wiki/Special:Random',
#  '/wiki/Wikipedia:About',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en',
#  '/wiki/Help:Contents',
#  '/wiki/Help:Introduction',
#  '/wiki/Wikipedia:Community_portal',
#  '/wiki/Special:RecentChanges',
#  '/wiki/Wikipedia:File_upload_wizard',
#  '/wiki/Special:WhatLinksHere/Python',
#  '/wiki/Special:RecentChangesLinked/Python',
#  '/wiki/Wikipedia:File_Upload_Wizard',
#  '/wiki/Special:SpecialPages',
#  '/w/index.php?title=Python&oldid=1134693155',
#  '/w/index.php?title=Python&action=info',
#  '/w/index.php?title=Special:CiteThisPage&page=Python&id=1134693155&wpFormIdentifier=titleform',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452',
#  '/w/index.php?title=Special:DownloadAsPdf&page=Python&action=show-download-screen',
#  '/w/index.php?title=Python&printable=yes',
#  'https://commons.wikimedia.org/wiki/Category:Python',
#  '#p-lang-btn',
#  '#',
#  '#Snakes',
#  '#Computing',
#  '#People',
#  '#Roller_coasters',
#  '#Vehicles',
#  '#Weaponry',
#  '#Other_uses',
#  '#See_also',
#  'https://af.wikipedia.org/wiki/Python',
#  'https://als.wikipedia.org/wiki/Python',
#  'https://ar.wikipedia.org/wiki/%D8%A8%D8%A7%D9%8A%D8%AB%D9%88%D9%86_(%D8%AA%D9%88%D8%B6%D9%8A%D8%AD)',
#  'https://az.wikipedia.org/wiki/Python_(d%C9%99qiql%C9%99%C5%9Fdirm%C9%99)',
#  'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)',
#  'https://be.wikipedia.org/wiki/Python',
#  'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)',
#  'https://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)',
#  'https://da.wikipedia.org/wiki/Python',
#  'https://de.wikipedia.org/wiki/Python',
#  'https://eo.wikipedia.org/wiki/Pitono_(apartigilo)',
#  'https://eu.wikipedia.org/wiki/Python_(argipena)',
#  'https://fa.wikipedia.org/wiki/%D9%BE%D8%A7%DB%8C%D8%AA%D9%88%D9%86',
#  'https://fr.wikipedia.org/wiki/Python',
#  'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%84%A0',
#  'https://hr.wikipedia.org/wiki/Python_(razdvojba)',
#  'https://io.wikipedia.org/wiki/Pitono',
#  'https://id.wikipedia.org/wiki/Python',
#  'https://ia.wikipedia.org/wiki/Python_(disambiguation)',
#  'https://is.wikipedia.org/wiki/Python_(a%C3%B0greining)',
#  'https://it.wikipedia.org/wiki/Python_(disambigua)',
#  'https://he.wikipedia.org/wiki/%D7%A4%D7%99%D7%AA%D7%95%D7%9F',
#  'https://ka.wikipedia.org/wiki/%E1%83%9E%E1%83%98%E1%83%97%E1%83%9D%E1%83%9C%E1%83%98_(%E1%83%9B%E1%83%A0%E1%83%90%E1%83%95%E1%83%90%E1%83%9A%E1%83%9B%E1%83%9C%E1%83%98%E1%83%A8%E1%83%95%E1%83%9C%E1%83%94%E1%83%9A%E1%83%9D%E1%83%95%E1%83%90%E1%83%9C%E1%83%98)',
#  'https://kg.wikipedia.org/wiki/Mboma_(nyoka)',
#  'https://la.wikipedia.org/wiki/Python_(discretiva)',
#  'https://lb.wikipedia.org/wiki/Python',
#  'https://hu.wikipedia.org/wiki/Python_(egy%C3%A9rtelm%C5%B1s%C3%ADt%C5%91_lap)',
#  'https://mr.wikipedia.org/wiki/%E0%A4%AA%E0%A4%BE%E0%A4%AF%E0%A4%A5%E0%A5%89%E0%A4%A8_(%E0%A4%86%E0%A4%9C%E0%A5%8D%E0%A4%9E%E0%A4%BE%E0%A4%B5%E0%A4%B2%E0%A5%80_%E0%A4%AD%E0%A4%BE%E0%A4%B7%E0%A4%BE)',
#  'https://nl.wikipedia.org/wiki/Python',
#  'https://ja.wikipedia.org/wiki/%E3%83%91%E3%82%A4%E3%82%BD%E3%83%B3',
#  'https://no.wikipedia.org/wiki/Pyton',
#  'https://pl.wikipedia.org/wiki/Pyton',
#  'https://pt.wikipedia.org/wiki/Python_(desambigua%C3%A7%C3%A3o)',
#  'https://ru.wikipedia.org/wiki/Python_(%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F)',
#  'https://sk.wikipedia.org/wiki/Python',
#  'https://sr.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%B2%D0%B8%D1%88%D0%B5%D0%B7%D0%BD%D0%B0%D1%87%D0%BD%D0%B0_%D0%BE%D0%B4%D1%80%D0%B5%D0%B4%D0%BD%D0%B8%D1%86%D0%B0)',
#  'https://sh.wikipedia.org/wiki/Python',
#  'https://fi.wikipedia.org/wiki/Python',
#  'https://sv.wikipedia.org/wiki/Pyton',
#  'https://th.wikipedia.org/wiki/%E0%B9%84%E0%B8%9E%E0%B8%97%E0%B8%AD%E0%B8%99',
#  'https://tr.wikipedia.org/wiki/Python_(anlam_ayr%C4%B1m%C4%B1)',
#  'https://uk.wikipedia.org/wiki/%D0%9F%D1%96%D1%84%D0%BE%D0%BD',
#  'https://ur.wikipedia.org/wiki/%D9%BE%D8%A7%D8%A6%DB%8C%D8%AA%DA%BE%D9%88%D9%86',
#  'https://vi.wikipedia.org/wiki/Python',
#  'https://zh.wikipedia.org/wiki/Python_(%E6%B6%88%E6%AD%A7%E4%B9%89)',
#  'https://www.wikidata.org/wiki/Special:EntityPage/Q747452#sitelinks-wikipedia',
#  '/wiki/Python',
#  '/wiki/Talk:Python',
#  '/wiki/Python',
#  '/w/index.php?title=Python&action=edit',
#  '/w/index.php?title=Python&action=history',
#  '/wiki/Python',
#  '/w/index.php?title=Python&action=edit',
#  '/w/index.php?title=Python&action=history',
#  'https://en.wiktionary.org/wiki/Python',
#  'https://en.wiktionary.org/wiki/python',
#  '/w/index.php?title=Python&action=edit&section=1',
#  '/wiki/Pythonidae',
#  '/wiki/Python_(genus)',
#  '/wiki/Python_(mythology)',
#  '/w/index.php?title=Python&action=edit&section=2',
#  '/wiki/Python_(programming_language)',
#  '/wiki/CMU_Common_Lisp',
#  '/wiki/PERQ#PERQ_3',
#  '/w/index.php?title=Python&action=edit&section=3',
#  '/wiki/Python_of_Aenus',
#  '/wiki/Python_(painter)',
#  '/wiki/Python_of_Byzantium',
#  '/wiki/Python_of_Catana',
#  '/wiki/Python_Anghelo',
#  '/w/index.php?title=Python&action=edit&section=4',
#  '/wiki/Python_(Efteling)',
#  '/wiki/Python_(Busch_Gardens_Tampa_Bay)',
#  '/wiki/Python_(Coney_Island,_Cincinnati,_Ohio)',
#  '/w/index.php?title=Python&action=edit&section=5',
#  '/wiki/Python_(automobile_maker)',
#  '/wiki/Python_(Ford_prototype)',
#  '/w/index.php?title=Python&action=edit&section=6',
#  '/wiki/Python_(missile)',
#  '/wiki/Python_(nuclear_primary)',
#  '/wiki/Colt_Python',
#  '/w/index.php?title=Python&action=edit&section=7',
#  '/wiki/Python_(codename)',
#  '/wiki/Python_(film)',
#  '/wiki/Monty_Python',
#  '/wiki/Python_(Monty)_Pictures',
#  '/wiki/Timon_of_Phlius',
#  '/w/index.php?title=Python&action=edit&section=8',
#  '/wiki/Cython',
#  '/wiki/Pyton',
#  '/wiki/Pithon',
#  '/wiki/File:Disambig_gray.svg',
#  '/wiki/Help:Disambiguation',
#  'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0',
#  'https://en.wikipedia.org/w/index.php?title=Python&oldid=1134693155',
#  '/wiki/Help:Category',
#  '/wiki/Category:Disambiguation_pages',
#  '/wiki/Category:Human_name_disambiguation_pages',
#  '/wiki/Category:Disambiguation_pages_with_given-name-holder_lists',
#  '/wiki/Category:Short_description_is_different_from_Wikidata',
#  '/wiki/Category:All_article_disambiguation_pages',
#  '/wiki/Category:All_disambiguation_pages',
#  '/wiki/Category:Animal_common_name_disambiguation_pages',
#  '//en.wikipedia.org/wiki/Wikipedia:Text_of_the_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#  '//creativecommons.org/licenses/by-sa/3.0/',
#  '//foundation.wikimedia.org/wiki/Terms_of_Use',
#  '//foundation.wikimedia.org/wiki/Privacy_policy',
#  '//www.wikimediafoundation.org/',
#  'https://foundation.wikimedia.org/wiki/Privacy_policy',
#  '/wiki/Wikipedia:About',
#  '/wiki/Wikipedia:General_disclaimer',
#  '//en.wikipedia.org/wiki/Wikipedia:Contact_us',
#  '//en.m.wikipedia.org/w/index.php?title=Python&mobileaction=toggle_view_mobile',
#  'https://developer.wikimedia.org',
#  'https://stats.wikimedia.org/#/en.wikipedia.org',
#  'https://foundation.wikimedia.org/wiki/Cookie_statement',
#  'https://wikimediafoundation.org/',
#  'https://www.mediawiki.org/']

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
usc = req.get(url).content
soup = bs(usc, 'html.parser')

# %%
usc = soup.find_all('div',class_='usctitlechanged')

# %%
usc[0].text
# Out:
# '\n\n          Title 2 - The Congress\n\n        '

# %%
usc_title = []
for i in usc:
    usc_title.append(i.get('usctitlechanged'))

# %%
len(usc_title)
# Out:
# 14

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
fbi = req.get(url).content
soup = bs(fbi, 'html.parser')

# %%
fbi = soup.find_all('h3',class_='title')

# %%
fbi[0].text.strip()
# Out:
# 'RUJA IGNATOVA'

# %%
fbi_names = []
for i in fbi:
    fbi_names.append(i.text.strip())
fbi_names
# Out:
# ['RUJA IGNATOVA',
#  'ARNOLDO JIMENEZ',
#  'OMAR ALEXANDER CARDENAS',
#  'ALEXIS FLORES',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ',
#  'MICHAEL JAMES PRATT',
#  'RAFAEL CARO-QUINTERO']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
html = req.get(url).content

sopa = bs(html, 'html.parser')

# %%
tabla = sopa.find_all('table')[3]

# %%
cabecera = tabla.find('thead')

# %%
res=[]

for e in cabecera.find_all('th'):
    res.append(e.text)
    
res[:2]
# Out:
# ['CitizenResponse', 'Date & Time UTC']

# %%
col_names = [e.text for e in cabecera.find_all('th')][1:7]

col_names
# Out:
# ['Date & Time UTC',
#  'Latitude degrees',
#  'Longitude degrees',
#  'Depth km',
#  'Mag  [+]',
#  'Region name  [+]']

# %%
cuerpo = tabla.find('tbody')

# %%
filas = cuerpo.find_all('tr')

# %%
filas[0].find('td', class_='tabev6').text.replace('\xa0\xa0\xa0', ' ')[10:31]
# Out:
# '2023-02-08 16:21:19.8'

# %%
date = [f.find('td', class_='tabev6').text.replace('\xa0\xa0\xa0', ' ')[10:31] for f in filas]

# %%
filas[0].find_all('td', class_='tabev1')[0].text.strip()
# Out:
# '19.15'

# %%
latitud = [f.find_all('td', class_='tabev1')[0].text.strip() for f in filas]

# %%
longitud = [f.find_all('td', class_='tabev1')[1].text.strip() for f in filas]

# %%
filas[0].find_all('td', class_='tabev2')[0].text.strip()
# Out:
# 'N'

# %%
lat_coord = [f.find_all('td', class_='tabev2')[0].text.strip() for f in filas]

# %%
lng_coord = [f.find_all('td', class_='tabev2')[1].text.strip() for f in filas]

# %%
magnitud = [f.find_all('td', class_='tabev2')[2].text.strip() for f in filas]

# %%
prof = [f.find('td', class_='tabev3').text for f in filas]

# %%
region = [f.find('td', class_='tb_region').text.strip() for f in filas]

# %%
df = pd.DataFrame(columns=col_names)

df
# Out:
# Empty DataFrame
# Columns: [Date & Time UTC, Latitude degrees, Longitude degrees, Depth km, Mag  [+], Region name  [+]]
# Index: []

# %%
df[col_names[0]] = date

df[col_names[1]] = latitud 

df[col_names[2]] = longitud

df[col_names[3]] = prof

df[col_names[4]] = magnitud

df[col_names[5]] = region

df
# Out:
#           Date & Time UTC Latitude degrees Longitude degrees Depth km  \
# 0   2023-02-08 16:21:19.8            19.15            155.48       33
# 1   2023-02-08 16:01:57.0             4.92            122.66       10
# 2   2023-02-08 16:01:04.0            38.15             38.61        2
# 3   2023-02-08 15:57:01.9             5.65            154.44      118
# 4   2023-02-08 15:56:50.9            37.32             37.07        5
# 5   2023-02-08 15:51:45.0             2.52            140.68       10
# 6   2023-02-08 15:49:59.4            37.84             36.61        5
# 7   2023-02-08 15:42:47.8            37.05             36.63       11
# 8   2023-02-08 15:40:34.0            37.23             36.96       17
# 9   2023-02-08 15:32:41.5             4.85             39.43       10
# 10  2023-02-08 15:29:29.0            42.05             73.92       45
# 11  2023-02-08 15:28:32.1            38.15             38.34        4
# 12  2023-02-08 15:25:58.3            39.02             40.81        1
# 13  2023-02-08 15:23:04.7            37.58             38.06       10
# 14  2023-02-08 15:22:32.2            19.17            155.49       33
# 15  2023-02-08 15:21:31.8            39.14             40.15        7
# 16  2023-02-08 15:16:17.8            16.76             86.10       10
# 17  2023-02-08 15:11:13.0            38.12             38.26       10
# 18  2023-02-08 15:07:23.8            38.54             37.76       89
# 19  2023-02-08 15:04:43.1            38.04             37.04        4
# 20  2023-02-08 15:00:05.9            38.12             37.24       24
# 21  2023-02-08 14:57:46.4            37.30             37.05        6
# 22  2023-02-08 14:55:50.9            38.11             38.53        5
# 23  2023-02-08 14:39:22.2            38.10             36.67        6
# 24  2023-02-08 14:38:15.0            34.53             70.37      131
# 25  2023-02-08 14:34:37.0            37.33             37.06        5
# 26  2023-02-08 14:33:22.8            38.11             36.18        3
# 27  2023-02-08 14:30:30.6            15.38             94.48       60
# 28  2023-02-08 14:28:48.9            37.25             36.79        8
# 29  2023-02-08 14:20:26.5            37.99             37.38        3
# 30  2023-02-08 14:17:21.5            38.10             36.64        7
# 31  2023-02-08 14:15:04.2            37.99             36.60       10
# 32  2023-02-08 14:12:16.6            38.13             37.96       10
# 33  2023-02-08 14:05:26.0            34.55            179.79      236
# 34  2023-02-08 14:04:57.0            38.03             38.21       10
# 35  2023-02-08 14:04:45.6            46.45              7.47        2
# 36  2023-02-08 13:50:19.8            19.26            155.41       30
# 37  2023-02-08 13:49:13.9            37.25             36.96        5
# 38  2023-02-08 13:36:51.6            37.80             37.93        5
# 39  2023-02-08 13:36:00.6            37.17             36.69        9
# 40  2023-02-08 13:33:20.3            38.11             37.75        5
# 41  2023-02-08 13:31:28.9            38.06             36.66        5
# 42  2023-02-08 13:29:31.8            36.32             35.98        5
# 43  2023-02-08 13:27:06.0            11.31            124.55        8
# 44  2023-02-08 13:22:45.9            37.99             38.21        3
# 45  2023-02-08 13:21:15.0             2.47            140.69       10
# 46  2023-02-08 13:18:44.3            38.10             36.59        5
# 47  2023-02-08 13:14:15.1            38.08             36.59        8
# 48  2023-02-08 13:10:17.9            37.59             33.01        6
# 49  2023-02-08 13:07:49.0            18.53             69.77       86
#
#    Mag  [+]                  Region name  [+]
# 0       2.0          ISLAND OF HAWAII, HAWAII
# 1       4.1               SULAWESI, INDONESIA
# 2       2.9                    EASTERN TURKEY
# 3       5.0       BOUGAINVILLE REGION, P.N.G.
# 4       3.1                    CENTRAL TURKEY
# 5       3.9  NEAR N COAST OF PAPUA, INDONESIA
# 6       4.3                    CENTRAL TURKEY
# 7       3.2                    CENTRAL TURKEY
# 8       2.7                    CENTRAL TURKEY
# 9       4.7                             KENYA
# 10      2.8     ISLA CHILOE, LOS LAGOS, CHILE
# 11      2.9                    EASTERN TURKEY
# 12      2.5                    EASTERN TURKEY
# 13      2.8                    EASTERN TURKEY
# 14      2.7          ISLAND OF HAWAII, HAWAII
# 15      2.7                    EASTERN TURKEY
# 16      5.5                 OFFSHORE HONDURAS
# 17      3.5                    EASTERN TURKEY
# 18      2.5                    CENTRAL TURKEY
# 19      4.2                    CENTRAL TURKEY
# 20      2.6                    CENTRAL TURKEY
# 21      2.6                    CENTRAL TURKEY
# 22      4.3                    EASTERN TURKEY
# 23      2.8                    CENTRAL TURKEY
# 24      2.9       LIBERTADOR O'HIGGINS, CHILE
# 25      3.0                    CENTRAL TURKEY
# 26      2.5                    CENTRAL TURKEY
# 27      4.1           OFFSHORE OAXACA, MEXICO
# 28      2.9                    CENTRAL TURKEY
# 29      5.1                    CENTRAL TURKEY
# 30      2.6                    CENTRAL TURKEY
# 31      2.7                    CENTRAL TURKEY
# 32      2.6                    CENTRAL TURKEY
# 33      4.2         SOUTH OF KERMADEC ISLANDS
# 34      3.8                    EASTERN TURKEY
# 35      1.3                       SWITZERLAND
# 36      2.5          ISLAND OF HAWAII, HAWAII
# 37      2.9                    CENTRAL TURKEY
# 38      2.9                    CENTRAL TURKEY
# 39      2.6                    CENTRAL TURKEY
# 40      3.5                    CENTRAL TURKEY
# 41      4.0                    CENTRAL TURKEY
# 42      3.7                    CENTRAL TURKEY
# 43      3.4                LEYTE, PHILIPPINES
# 44      3.7                    EASTERN TURKEY
# 45      4.3  NEAR N COAST OF PAPUA, INDONESIA
# 46      3.1                    CENTRAL TURKEY
# 47      3.5                    CENTRAL TURKEY
# 48      3.0                    CENTRAL TURKEY
# 49      3.2                   TARAPACA, CHILE

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
html = req.get(url).content


sopa = bs(html, 'html.parser')

sopa.find_all('div')
# Out:
# [<div id="contenu"><!-- Start container -->
#  <div id="bandeau"><style> .ban022{background:url('https://static1.emsc.eu/Css/img/spriteBannApp.jpg') no-repeat;} .ban0{background:#B40015;/*#000;*/width:100%;height:100%;border:0;} .ban1{vertical-align:top;text-align:center;padding-top:4px;width:150px;}
#  			.ban2{position:relative; vertical-align:middle;text-align:center; color:#fff; background-position:0px -41px;/*10px -41px;*/}
#  			.ban3{width:140px;padding-left:5px;text-align:center;background-position:-640px -41px;}
#  			#ejs_server_heure {position:absolute; bottom:0; width:100%;}
#  			#bandeau{background:#B40015;}</style><table cellpadding="0" cellspacing="0" class="ban0"><tr><td class="ban1" onclick="window.location.href='https://www.emsc-csem.org';" onmouseover="this.style.cursor='pointer';">
#  <img alt="logo - home" src="https://static2.emsc.eu/Css/img/logo.png" style="width:150px;height:81px;"/></td>
#  <td class="ban2 ban022" onclick="window.location.href='https://www.emsc-csem.org';" onmouseover="this.style.cursor='pointer';">
#  <div style="border:0; position:relative; float:right; width:110px; height:80px; margin-top:-5px; margin-right:25px; ">
#  <div id="androidstore" style="border:0; position:relative; float:left; width:110px; height:35px;"></div>
#  <div id="iosstore" style="border:0; position:relative; float:left; width:110px; height:35px; margin-top:8px;"></div>
#  </div>
#  <script type="text/javascript">set_server_date(2023,2,8,16,25,36)</script>
#  <div id="ejs_server_heure">Current time: 2023-02-08 16:25:36 UTC</div>
#  </td>
#  <td align="right" class="ban3 ban022"><div class="login_box" id="login_box"><form action="https://www.emsc-csem.org/Member/" enctype="multipart/form-data" method="post">
#  <table cellpadding="0" cellspacing="0" style="width:100%;height:100%;border:0;"><tr><td colspan="2" style="text-align: center; font-size: 11px; font-weight: bold; color: #fff;">
#  <span class="spriteorig sp_lock vbottom"></span> Member access</td></tr><tr><td colspan="2" style="height: 2px;text-align:center;">
#  <img alt="" src="..." style="display: block;width:1px;border:0;height:2px;"/></td></tr>
#  <tr><td style="font-size: 11px; font-weight: bold; text-align: left; color: #000;">Name </td>
#  <td style="text-align:left;"><input maxlength="10" name="login" size="8" style="height: 11px; width: 80px; font-size: 11px;" type="text"/></td></tr>
#  <tr><td colspan="2" style="height: 2px;text-align:center;"><img alt="" src="..." style="display: block;width:1px; border:0;height:2px;"/></td></tr>
#  <tr><td style="font-size: 11px; font-weight: bold; text-align: left; color: #000;">Pwd</td>
#  <td style="text-align:left;"><input maxlength="32" name="pwd" size="8" style="height: 11px; width: 80px; font-size: 11px;" type="password"/></td></tr>
#  <tr><td colspan="2" style="height: 2px;text-align:center;"><img alt="" src="..." style="display: block;width:1px;border:0;height:2px;"/></td>
#  </tr><tr><td> </td><td style="text-align:left;"><input style="height: 20px; font-size: 11px;" type="submit" value="Sign in"/></td></tr></table></form></div></td></tr></table><script>
#  			$jq(function(){
#  				$jq("#androidstore").bind("click", function(e) { e.preventDefault(); e.stopPropagation(); $jq.post("/indexAjaxApp.php", { linkto:"android",from:"site"}, function () {});  window.open("https://play.google.com/store/apps/details?id=org.emsc_csem.lastquake","_blank"); });
#  				$jq("#iosstore").bind("click", function(e) { e.preventDefault(); e.stopPropagation(); $jq.post("/indexAjaxApp.php", { linkto:"ios",from:"site" }, function () {});  window.open("https://itunes.apple.com/us/app/lastquake/id890799748","_blank"); });
#
#  			});
#  			</script>
#  </div>
#  <ul id="nav">
#  <!-- earthquake level 0 -->
#  <li><a href="https://www.emsc-csem.org/Earthquake/info.php">Earthquake information</a>
#  <ul>
#  <li><a href="https://www.emsc-csem.org/Earthquake/">List of latest earthquakes</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/significant_earthquakes.php">Significant earthquakes</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/?filter=yes">Search earthquakes</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/Map/gmap.php">Earthquakes interactive map</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/near_you.php">Earthquakes near you</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/felt.php">Felt earthquakes</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/News/">Special reports</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/seismicity/real_time.php">How it works</a></li>
#  </ul></li>
#  <!-- search level 0 -->
#  <li><a href="https://www.emsc-csem.org/Earthquake/Contribute/?lang=tr" onmouseout="info_b('notshow','','');" onmouseover="info_b('show','The flag is the visible language that seems to be the most appropriate to respond to our questionnaire.','Language');"><img id="flag" src="https://static2.emsc.eu/Images/flag/flag_tr.png" style="vertical-align:middle;height:12px;width:18px;"/>  Testimonies, photos</a>
#  <ul>
#  <li><a href="https://www.emsc-csem.org/Earthquake/Gallery/">Photos</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/Testimonies/">Testimonies</a></li>
#  </ul></li>
#  <!-- data level 0 -->
#  <li><a href="https://www.emsc-csem.org/service/">Information services</a>
#  <ul>
#  <li><a href="https://www.emsc-csem.org/service/lastquakers/"><span style="display:inline-block;background:url(https://static3.emsc.eu/Css/img/lastquakers_16px.png) no-repeat;width:16px;height:16px;vertical-align:middle;"></span> LastQuakers community (NEW)</a></li>
#  <li><a href="https://www.emsc-csem.org/service/real_time/"><span class="spriteorig sp_phone" style="vertical-align:middle;"></span> For smartphones</a></li>
#  <li><a href="https://www.emsc-csem.org/service/application/"><span class="spriteorig sp_phone" style="vertical-align:middle;"></span> Android &amp; iOS App</a></li>
#  <li><a href="https://www.emsc-csem.org/service/Browser-extension/"><span style="display:inline-block;background:url(https://static3.emsc.eu/Css/img/extension-icon.png) no-repeat;width:16px;height:16px;vertical-align:middle;"></span> Browser extensions</a></li>
#  <li><a href="https://www.seismicportal.eu/webservices.html"><span class="spriteorig sp_feed-icon14" style="vertical-align:middle;"></span> Webservices</a></li>
#  <li><a href="https://www.emsc-csem.org/service/rss/"><span class="spriteorig sp_feed-icon14" style="vertical-align:middle;"></span> RSS feeds</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/Map/earth/"><span class="spriteorig sp_ge2" style="vertical-align:middle;"></span> Seismicity on Google Earth</a></li>
#  <li><a href="https://www.emsc-csem.org/service/register.php"><span class="spriteorig sp_alert1" style="vertical-align:middle;"></span> Email notification service</a></li>
#  </ul></li>
#  <!-- seismicity level 0 -->
#  <li><a href="https://www.emsc-csem.org/Earthquake/for_seismologist.php">For seismologists</a>
#  <ul>
#  <li><a href="https://www.emsc-csem.org/Earthquake/seismologist.php">Latest data contributions</a></li>
#  <li><a href="https://www.emsc-csem.org/Earthquake/index_tensors.php">Moment tensors</a></li>
#  <li><a href="https://www.emsc-csem.org/Bulletin/">Euro-Med bulletin</a></li>
#  <li><a href="https://www.seismicportal.eu/" target="_blank">Seismic Portal</a></li>
#  <li><a href="https://www.emsc-csem.org/News/">News</a></li>
#  <li><a href="https://www.emsc-csem.org/job/">Jobs</a></li>
#  </ul></li>
#  <!-- project level 0 -->
#  <li><a href="https://www.emsc-csem.org/Project/">Projects</a>
#  <ul>
#  <li><a href="https://www.emsc-csem.org/Project/#aristotle">ARISTOTLE</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#carismand">CARISMAND</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#improver">IMPROVER</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#seismic">Seismic portal</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#citizen">Citizen seismology</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#qcn">Quake Catcher Network</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#sigma">Sigma</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#verce">Verce</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#marsite">MARsite</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#nera">NERA</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#EPOS">EPOS</a></li>
#  <li><a href="https://www.emsc-csem.org/Project/#REAKT">REAKT</a></li>
#  </ul></li>
#  <!-- publi level 0 -->
#  <li><a href="https://www.emsc-csem.org/Documents/">Publications &amp; docs</a></li>
#  </ul><div class="clearer"></div><div class="clearer"></div>
#  <div id="sitemap"><i>You are here : </i>
#  <a href="https://www.emsc-csem.org">EMSC</a> &gt; Earthquake &gt; Real Time Seismicity
#  		<div>Our sponsors:
#  		<span id="sponsor"><a href="http://www.digitalelement.com/" target="_blank">digitalelement<div id="sponimg"><img src="https://static3.emsc.eu/Images/sites/p_netacuity_01.gif"/></div></a></span>
#  <a href="/Donate/"><span class="spriteorig sp_btn_donate_SM" style="vertical-align:middle;margin-top:-2px;"></span></a>    <a href="/about/">About EMSC</a></div>
#  </div><style type="text/css">
#  		#sitemap div, x:-moz-any-link {margin-top:-13px;} /* Firefox 2*/
#  		#sitemap div, x:-moz-any-link, x:default {margin-top:0;} /* Firefox >=3*/
#  		#sponsor{margin-right:15px;}
#  		div#sponimg{position:absolute; display:none; padding:20px; background:rgba(0,0,0,.8);vertical-align:middle;} #sponsor a:hover>div { display: block; }
#  		div#sponimg img{vertical-align:middle;}
#  	</style>
#  <!--[if lte IE 7]><style type="text/css">#sitemap div{ margin-top:-13px;} </style><![endif]-->
#  <script> var sponsor = {
#  		_sp:{"netacuity":{"logo":"https:\/\/static3.emsc.eu\/Images\/sites\/p_netacuity_01.gif","link":"http:\/\/www.digitalelement.com\/","name":"digitalelement"},"geosig":{"logo":"https:\/\/static1.emsc.eu\/Images\/sites\/geosig_logo.jpg","text":"Strong motion instrumentation with a focus on Earthquake Early Warning<br>","link":"http:\/\/www.geosig.com\/","name":"GeoSIG"},"scor":{"logo":"https:\/\/static2.emsc.eu\/Images\/sites\/scor.png","link":"https:\/\/www.scor.com\/en\/scor-corporate-foundation-science","name":"SCOR"}}, _i:0, _keys:null,
#  		_start:function() {
#  			this._keys = Object.keys(this._sp);
#  		},
#  		_next: function() {
#  			this._i++;
#  			if(this._i >= this._keys.length) this._i=0;
#  			var k=this._keys[this._i]; //console.log(this._keys.length, k, this._i);
#  			//console.log( $jq("#sponsor a").contents());
#  			$jq("#sponsor a").attr("href",this._sp[k]["link"]);
#  			$jq("#sponsor a").contents()[0].textContent=this._sp[k]["name"]; $jq("#sponimg img").attr("src",this._sp[k]["logo"]);
#  			var self=this;
#  			setTimeout(function() {self._next();},1000*40);
#  		}
#  	}
#  	$jq(function() {
#  		//console.log( "ready!" );
#  		sponsor._start();
#  		sponsor._next();
#  	});
#  	</script>
#  <div id="info_bulle"><div class="inf_t" id="inf_t"></div><div class="inf_te" id="inf_te"></div></div>
#  <div id="info_bulle2"><div class="inf_seul" id="inf_seul"></div></div>
#  <div id="content"><!-- Start content --><div id="bann_defile"><span class="markee" id="markee_bann_defile" name="markee_bann_defile">temp</span><span id="bann_disclam" style="display:none;"><a href="/disclaimer.php">Disclaimer</a></span></div>
#  <h1><span>Real Time Seismicity</span></h1><!-- ============ TITRE ===================== --><div id="quick_access" style="font-size:11px;text-align:center; margin-bottom:5px;">
#  <a href="/Earthquake/?filter=yes"><span class="spriteorig sp_Icon_tools_th" style="margin-right:3px;"></span>Define your criteria</a> to find specific events  -  Quick search:
#  	<a href="/Earthquake/world/M3/"> mag≥3 </a> | <a href="/Earthquake/world/M4/"> mag≥4 </a> | <a href="/Earthquake/world/M5/"> mag≥5 </a>
#  </div><style type="text/css"> .npages { height:30px; text-align:center; font-weight:bold; } .npages td { border-bottom: 2px solid #EDF3FE;} a.sublink { /*height:18px;*/ padding:5px 10px; border:1px solid #ccc; margin:0 4px; text-decoration:underline; background-color:#fff;}
#  			a.sublinka { color:#000; text-decoration:none; font-weight:normal; background-color:#FFFFCC; /*rgb(255,255,0);*/ background-color:rgba(255,255,0,0.3); }
#  			</style>
#  <!--[if IE]>
#  			<style type="text/css">
#  			.sublinka { background:transparent; filter:progid:DXImageTransform.Microsoft.gradient(startColorstr=#FFFFFFCC,endColorstr=#FFFFFFCC); zoom:1; opacity:0.9; } .sublink {zoom:1;}
#  			</style>
#  			<![endif]--> <link href="https://static3.emsc.eu/Css/tableau_event.css" rel="stylesheet" type="text/css"/>
#  <style type="text/css">
#  			@media print {
#  				tbody td {font-size:10px; } .comment { font-size:7px; width:78px;} .tabev3 { padding-right:15px; } .tabev2 { padding-right:2px; } .tabev5 { padding-right:0; padding-left:2px; } .tabev6 { width:140px; }
#  				.pagelist,.autour,.tb_infos,.npages {display:none;}	.black td{border-top:1px solid black;} #quick_access{display:none;}
#  			}
#  			</style><script> addjs_after("https://static1.emsc.eu/javascript/tri_tableau.js");
#  							addjs_after("https://static2.emsc.eu/javascript/tableau_tri_event.js");
#  				</script><table style="width:99%;"><tr class="tb_infos"><td><span class="spriteorig sp_info"></span> - Sorting by column is performed on the data of the current page.</td><td style="text-align:right;"><a href="/glossary.php">Glossary</a></td></tr></table><script> var scrollable=false; </script><table border="0" cellpadding="0" cellspacing="0" width="100%"><thead>
#  <tr>
#  <td colspan="13" style="background: white;height: 1px"></td>
#  </tr>
#  <tr id="haut_tableau"><th class="th2 th3" colspan="3" style="width:90px;display:table-csell;"><div onmouseout="info_b('notshow','','');" onmouseover="info_b('show','Represents the results of information provided by users (Felt earthquake, pictures, testimonies ,...)&lt;br&gt;See an intensity map for more details on the macroseismic intensity scale.','Citizen response');">Citizen<br/>Response</div><br/><table cellpadding="0" cellspacing="0" style="width:100%;margin:0;text-align:center;"><tr><td><div onclick="change_tri('im_report');" onmouseout="change_image(this,'out','im_report');" onmouseover="change_image(this,'over','im_report');"><span class="spriteorig sp_ico_list" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Sorted by number of &lt;b&gt;Comments&lt;/b&gt;');"></span><span class="spriteorig sp_s_asc" id="im_report" style="display:none;"></span></div></td><td><div onclick="change_tri('im_pics');" onmouseout="change_image(this,'out','im_pics');" onmouseover="change_image(this,'over','im_pics');"><span class="spriteorig sp_digikam" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Sorted by number of &lt;b&gt;Pictures&lt;/b&gt;');"></span><span class="spriteorig sp_s_asc" id="im_pics" style="display:none;"></span></div></td><td><div onclick="change_tri('im_intens');" onmouseout="change_image(this,'out','im_intens');" onmouseover="change_image(this,'over','im_intens');"><span class="spriteorig sp_IntensityMap" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Sorted by &lt;b&gt;Macroseismic Intensity&lt;/b&gt;');"></span><span class="spriteorig sp_s_asc" id="im_intens" style="display:none;"></span></div></td></tr></table></th><th class="th2" onclick="change_tri('im_time');" onmouseout="change_image(this,'out','im_time');" onmouseover="change_image(this,'over','im_time');">Date &amp; Time <span class="spriteorig sp_s_desc" id="im_select"></span><div style="font-weight:normal;">UTC</div></th><th class="th2" colspan="2" onclick="change_tri('im_lat');" onmouseout="change_image(this,'out','im_lat');" onmouseover="change_image(this,'over','im_lat');">Latitude <span class="spriteorig sp_s_asc" id="im_lat" style="display:none;"></span><div style="font-weight:normal;">degrees</div></th><th class="th2" colspan="2" onclick="change_tri('im_lon');" onmouseout="change_image(this,'out','im_lon');" onmouseover="change_image(this,'over','im_lon');">Longitude <span class="spriteorig sp_s_asc" id="im_lon" style="display:none;"></span><div style="font-weight:normal;">degrees</div></th><th class="th2" onclick="change_tri('im_depth');" onmouseout="change_image(this,'out','im_depth');" onmouseover="change_image(this,'over','im_depth');">Depth <span class="spriteorig sp_s_asc" id="im_depth" style="display:none;"></span><div style="font-weight: normal">km</div></th><th class="th2" colspan="1" id="thmag"><div onclick="change_tri('im_mag');" onmouseout="change_image(this,'out','im_mag');" onmouseover="change_image(this,'over','im_mag');" style="float:left;">Mag <span class="spriteorig sp_s_asc" id="im_mag" style="display:none;"></span></div><div id="magplus2" style="float:left;"> <a href="javascript:hide_magni();" id="magplus" style="color:white;">[+]</a></div></th><th class="th2" id="ex_th2"><div onclick="change_tri('im_reg');" onmouseout="change_image(this,'out','im_reg');" onmouseover="change_image(this,'over','im_reg');" style="float:left;">Region name <span class="spriteorig sp_s_asc" id="im_reg" style="display:none;"></span></div><div id="upda" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Show last update');"> <a href="javascript:hide_upd();" style="color:white;">[+]</a></div></th><th class="th2 updatetimeno" id="upd"><div id="labupd" onclick="change_tri('im_upd');" onmouseout="change_image(this,'out','im_upd');" onmouseover="change_image(this,'over','im_upd');" style="float:left;text-align:right;">Last update <span class="spriteorig sp_s_asc" id="im_upd" style="display:none; ...
#  <tr><td colspan="13" style="background: white;height: 1px"></td></tr>
#  <tr class="npages" id="my_pagelist_0"><td colspan="13"><a class="sublink sublinka" href="javascript:void()" rel="nofollow">1</a><a class="sublink" href="/Earthquake/?view=2">2</a><a class="sublink" href="/Earthquake/?view=3">3</a><a class="sublink" href="/Earthquake/?view=4">4</a><a class="sublink" href="/Earthquake/?view=5">5</a><a class="sublink" href="/Earthquake/?view=6">6</a><a class="sublink" href="/Earthquake/?view=7">7</a><a class="sublink" href="/Earthquake/?view=8">8</a><a class="sublink" href="/Earthquake/?view=9">9</a><a class="sublink" href="/Earthquake/?view=10">10</a><a alt="Next page" class="sublink" href="/Earthquake/?view=2">›</a><a alt="Next 10 pages" class="sublink" href="/Earthquake/?view=11">»</a></td></tr></thead><tbody id="tbody"><tr class="ligne1 normal" id="1220381" onclick="go_details(event,1220381);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220381">2023-02-08   16:21:19.8</a></b><i class="ago" id="ago0">04min ago</i></td><td class="tabev1">19.15 </td><td class="tabev2">N  </td><td class="tabev1">155.48 </td><td class="tabev2">W  </td><td class="tabev3">33</td><td class="tabev5" id="magtyp0">Md</td><td class="tabev2">2.0</td><td class="tb_region" id="reg0"> ISLAND OF HAWAII, HAWAII</td><td class="comment updatetimeno" id="upd0" style="text-align:right;">2023-02-08 16:24</td></tr>
#  <tr class="ligne2 normal" id="1220374" onclick="go_details(event,1220374);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220374&amp;f=/FELTREPORTS/122/1220374/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220374">2023-02-08   16:01:57.0</a></b><i class="ago" id="ago1">23min ago</i></td><td class="tabev1">4.92 </td><td class="tabev2">S  </td><td class="tabev1">122.66 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp1"> M</td><td class="tabev2">4.1</td><td class="tb_region" id="reg1"> SULAWESI, INDONESIA</td><td class="comment updatetimeno" id="upd1" style="text-align:right;">2023-02-08 16:10</td></tr>
#  <tr class="ligne1 normal" id="1220380" onclick="go_details(event,1220380);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220380">2023-02-08   16:01:04.0</a></b><i class="ago" id="ago2">24min ago</i></td><td class="tabev1">38.15 </td><td class="tabev2">N  </td><td class="tabev1">38.61 </td><td class="tabev2">E  </td><td class="tabev3">2</td><td class="tabev5" id="magtyp2">ML</td><td class="tabev2">2.9</td><td class="tb_region" id="reg2"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd2" style="text-align:right;">2023-02-08 16:22</td></tr>
#  <tr class="ligne2 normal" id="1220375" onclick="go_details(event,1220375);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220375">2023-02-08   15:57:01.9</a></b><i class="ago" id="ago3">28min ago</i></td><td class="tabev1">5.65 </td><td class="tabev2">S  </td><td class="tabev1">154.44 </td><td class="tabev2">E  </td><td class="tabev3">118</td><td class="tabev5" id="magtyp3">mb</td><td class="tabev2">5.0</td><td class="tb_region" id="reg3"> BOUGAINVILLE REGION, P.N.G.</td><td class="comment updatetimeno" id="upd3" style="text-align:right;">2023-02-08 16:21</td></tr>
#  <tr class="ligne1 normal" id="1220373" onclick="go_details(event,1220373);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220373" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;testimony&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">1</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220373&amp;f=/FELTREPORTS/122/1220373/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#00FFFF;">IV</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220373">2023-02-08   15:56:50.9</a></b><i class="ago" id="ago4">28min ago</i></td><td class="tabev1">37.32 </td><td class="tabev2">N  </td><td class="tabev1">37.07 </td><td class="tabev2">E  </td><td class="tabev3">5</td><td class="tabev5" id="magtyp4">ML</td><td class="tabev2">3.1</td><td class="tb_region" id="reg4"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd4" style="text-align:right;">2023-02-08 16:09</td></tr>
#  <tr class="ligne2 normal" id="1220369" onclick="go_details(event,1220369);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220369&amp;f=/FELTREPORTS/122/1220369/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220369">2023-02-08   15:51:45.0</a></b><i class="ago" id="ago5">33min ago</i></td><td class="tabev1">2.52 </td><td class="tabev2">S  </td><td class="tabev1">140.68 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp5"> M</td><td class="tabev2">3.9</td><td class="tb_region" id="reg5"> NEAR N COAST OF PAPUA, INDONESIA</td><td class="comment updatetimeno" id="upd5" style="text-align:right;">2023-02-08 16:05</td></tr>
#  <tr class="ligne1 normal" id="1220365" onclick="go_details(event,1220365);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220365" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;11 testimonies&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">11</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220365&amp;f=/FELTREPORTS/122/1220365/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#66CCFF;">III</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220365">2023-02-08   15:49:59.4</a></b><i class="ago" id="ago6">35min ago</i></td><td class="tabev1">37.84 </td><td class="tabev2">N  </td><td class="tabev1">36.61 </td><td class="tabev2">E  </td><td class="tabev3">5</td><td class="tabev5" id="magtyp6">ML</td><td class="tabev2">4.3</td><td class="tb_region" id="reg6"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd6" style="text-align:right;">2023-02-08 16:04</td></tr>
#  <tr class="ligne2 normal" id="1220368" onclick="go_details(event,1220368);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220368" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;7 testimonies&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">7</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220368&amp;f=/FELTREPORTS/122/1220368/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#66CCFF;">III</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220368">2023-02-08   15:42:47.8</a></b><i class="ago" id="ago7">42min ago</i></td><td class="tabev1">37.05 </td><td class="tabev2">N  </td><td class="tabev1">36.63 </td><td class="tabev2">E  </td><td class="tabev3">11</td><td class="tabev5" id="magtyp7">ML</td><td class="tabev2">3.2</td><td class="tb_region" id="reg7"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd7" style="text-align:right;">2023-02-08 15:55</td></tr>
#  <tr class="ligne1 normal" id="1220371" onclick="go_details(event,1220371);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220371" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;testimony&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">1</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220371&amp;f=/FELTREPORTS/122/1220371/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220371">2023-02-08   15:40:34.0</a></b><i class="ago" id="ago8">45min ago</i></td><td class="tabev1">37.23 </td><td class="tabev2">N  </td><td class="tabev1">36.96 </td><td class="tabev2">E  </td><td class="tabev3">17</td><td class="tabev5" id="magtyp8">ML</td><td class="tabev2">2.7</td><td class="tb_region" id="reg8"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd8" style="text-align:right;">2023-02-08 16:07</td></tr>
#  <tr class="ligne2 normal" id="1220363" onclick="go_details(event,1220363);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220363&amp;f=/FELTREPORTS/122/1220363/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220363">2023-02-08   15:32:41.5</a></b><i class="ago" id="ago9">52min ago</i></td><td class="tabev1">4.85 </td><td class="tabev2">S  </td><td class="tabev1">39.43 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp9">mb</td><td class="tabev2">4.7</td><td class="tb_region" id="reg9"> KENYA</td><td class="comment updatetimeno" id="upd9" style="text-align:right;">2023-02-08 16:05</td></tr>
#  <tr class="ligne1 normal" id="1220360" onclick="go_details(event,1220360);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220360">2023-02-08   15:29:29.0</a></b><i class="ago" id="ago10">56min ago</i></td><td class="tabev1">42.05 </td><td class="tabev2">S  </td><td class="tabev1">73.92 </td><td class="tabev2">W  </td><td class="tabev3">45</td><td class="tabev5" id="magtyp10"> M</td><td class="tabev2">2.8</td><td class="tb_region" id="reg10"> ISLA CHILOE, LOS LAGOS, CHILE</td><td class="comment updatetimeno" id="upd10" style="text-align:right;">2023-02-08 15:45</td></tr>
#  <tr class="ligne2 normal" id="1220359" onclick="go_details(event,1220359);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220359">2023-02-08   15:28:32.1</a></b><i class="ago" id="ago11">57min ago</i></td><td class="tabev1">38.15 </td><td class="tabev2">N  </td><td class="tabev1">38.34 </td><td class="tabev2">E  </td><td class="tabev3">4</td><td class="tabev5" id="magtyp11">ML</td><td class="tabev2">2.9</td><td class="tb_region" id="reg11"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd11" style="text-align:right;">2023-02-08 15:39</td></tr>
#  <tr class="ligne1 normal" id="1220364" onclick="go_details(event,1220364);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220364">2023-02-08   15:25:58.3</a></b><i class="ago" id="ago12">59min ago</i></td><td class="tabev1">39.02 </td><td class="tabev2">N  </td><td class="tabev1">40.81 </td><td class="tabev2">E  </td><td class="tabev3">1</td><td class="tabev5" id="magtyp12">ML</td><td class="tabev2">2.5</td><td class="tb_region" id="reg12"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd12" style="text-align:right;">2023-02-08 15:51</td></tr>
#  <tr class="ligne2 normal" id="1220358" onclick="go_details(event,1220358);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220358">2023-02-08   15:23:04.7</a></b><i class="ago" id="ago13">1hr 02min ago</i></td><td class="tabev1">37.58 </td><td class="tabev2">N  </td><td class="tabev1">38.06 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp13">ML</td><td class="tabev2">2.8</td><td class="tb_region" id="reg13"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd13" style="text-align:right;">2023-02-08 15:30</td></tr>
#  <tr class="ligne1 normal" id="1220355" onclick="go_details(event,1220355);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220355">2023-02-08   15:22:32.2</a></b><i class="ago" id="ago14">1hr 03min ago</i></td><td class="tabev1">19.17 </td><td class="tabev2">N  </td><td class="tabev1">155.49 </td><td class="tabev2">W  </td><td class="tabev3">33</td><td class="tabev5" id="magtyp14">Md</td><td class="tabev2">2.7</td><td class="tb_region" id="reg14"> ISLAND OF HAWAII, HAWAII</td><td class="comment updatetimeno" id="upd14" style="text-align:right;">2023-02-08 15:25</td></tr>
#  <tr class="ligne2 normal" id="1220357" onclick="go_details(event,1220357);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220357">2023-02-08   15:21:31.8</a></b><i class="ago" id="ago15">1hr 04min ago</i></td><td class="tabev1">39.14 </td><td class="tabev2">N  </td><td class="tabev1">40.15 </td><td class="tabev2">E  </td><td class="tabev3">7</td><td class="tabev5" id="magtyp15">ML</td><td class="tabev2">2.7</td><td class="tb_region" id="reg15"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd15" style="text-align:right;">2023-02-08 15:30</td></tr>
#  <tr class="ligne1 bold" id="1220353" onclick="go_details(event,1220353);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220353" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;12 testimonies&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">12</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220353&amp;f=/FELTREPORTS/122/1220353/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#00FFFF;">IV</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220353">2023-02-08   15:16:17.8</a></b><i class="ago" id="ago16">1hr 09min ago</i></td><td class="tabev1">16.76 </td><td class="tabev2">N  </td><td class="tabev1">86.10 </td><td class="tabev2">W  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp16">Mw</td><td class="tabev2">5.5</td><td class="tb_region" id="reg16"> OFFSHORE HONDURAS</td><td class="comment updatetimeno" id="upd16" style="text-align:right;">2023-02-08 16:01</td></tr>
#  <tr class="ligne2 normal" id="1220354" onclick="go_details(event,1220354);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220354" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;testimony&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">1</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220354&amp;f=/FELTREPORTS/122/1220354/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#66CCFF;">III</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220354">2023-02-08   15:11:13.0</a></b><i class="ago" id="ago17">1hr 14min ago</i></td><td class="tabev1">38.12 </td><td class="tabev2">N  </td><td class="tabev1">38.26 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp17">ML</td><td class="tabev2">3.5</td><td class="tb_region" id="reg17"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd17" style="text-align:right;">2023-02-08 15:22</td></tr>
#  <tr class="ligne1 normal" id="1220350" onclick="go_details(event,1220350);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220350">2023-02-08   15:07:23.8</a></b><i class="ago" id="ago18">1hr 18min ago</i></td><td class="tabev1">38.54 </td><td class="tabev2">N  </td><td class="tabev1">37.76 </td><td class="tabev2">E  </td><td class="tabev3">89</td><td class="tabev5" id="magtyp18">ML</td><td class="tabev2">2.5</td><td class="tb_region" id="reg18"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd18" style="text-align:right;">2023-02-08 15:13</td></tr>
#  <tr class="ligne2 normal" id="1220348" onclick="go_details(event,1220348);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220348" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;4 testimonies&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">4</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220348&amp;f=/FELTREPORTS/122/1220348/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#66CCFF;">III</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220348">2023-02-08   15:04:43.1</a></b><i class="ago" id="ago19">1hr 20min ago</i></td><td class="tabev1">38.04 </td><td class="tabev2">N  </td><td class="tabev1">37.04 </td><td class="tabev2">E  </td><td class="tabev3">4</td><td class="tabev5" id="magtyp19">ML</td><td class="tabev2">4.2</td><td class="tb_region" id="reg19"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd19" style="text-align:right;">2023-02-08 15:31</td></tr>
#  <tr class="ligne1 normal" id="1220349" onclick="go_details(event,1220349);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220349">2023-02-08   15:00:05.9</a></b><i class="ago" id="ago20">1hr 25min ago</i></td><td class="tabev1">38.12 </td><td class="tabev2">N  </td><td class="tabev1">37.24 </td><td class="tabev2">E  </td><td class="tabev3">24</td><td class="tabev5" id="magtyp20">ML</td><td class="tabev2">2.6</td><td class="tb_region" id="reg20"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd20" style="text-align:right;">2023-02-08 15:08</td></tr>
#  <tr class="ligne2 normal" id="1220346" onclick="go_details(event,1220346);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220346">2023-02-08   14:57:46.4</a></b><i class="ago" id="ago21">1hr 27min ago</i></td><td class="tabev1">37.30 </td><td class="tabev2">N  </td><td class="tabev1">37.05 </td><td class="tabev2">E  </td><td class="tabev3">6</td><td class="tabev5" id="magtyp21">ML</td><td class="tabev2">2.6</td><td class="tb_region" id="reg21"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd21" style="text-align:right;">2023-02-08 15:02</td></tr>
#  <tr class="ligne1 normal" id="1220345" onclick="go_details(event,1220345);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220345" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;testimony&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">1</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220345&amp;f=/FELTREPORTS/122/1220345/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#00FFFF;">IV</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220345">2023-02-08   14:55:50.9</a></b><i class="ago" id="ago22">1hr 29min ago</i></td><td class="tabev1">38.11 </td><td class="tabev2">N  </td><td class="tabev1">38.53 </td><td class="tabev2">E  </td><td class="tabev3">5</td><td class="tabev5" id="magtyp22">ML</td><td class="tabev2">4.3</td><td class="tb_region" id="reg22"> EASTERN TURKEY</td><td class="comment updatetimeno" id="upd22" style="text-align:right;">2023-02-08 15:26</td></tr>
#  <tr class="ligne2 normal" id="1220341" onclick="go_details(event,1220341);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220341">2023-02-08   14:39:22.2</a></b><i class="ago" id="ago23">1hr 46min ago</i></td><td class="tabev1">38.10 </td><td class="tabev2">N  </td><td class="tabev1">36.67 </td><td class="tabev2">E  </td><td class="tabev3">6</td><td class="tabev5" id="magtyp23">ML</td><td class="tabev2">2.8</td><td class="tb_region" id="reg23"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd23" style="text-align:right;">2023-02-08 14:52</td></tr>
#  <tr class="ligne1 normal" id="1220344" onclick="go_details(event,1220344);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220344">2023-02-08   14:38:15.0</a></b><i class="ago" id="ago24">1hr 47min ago</i></td><td class="tabev1">34.53 </td><td class="tabev2">S  </td><td class="tabev1">70.37 </td><td class="tabev2">W  </td><td class="tabev3">131</td><td class="tabev5" id="magtyp24"> M</td><td class="tabev2">2.9</td><td class="tb_region" id="reg24"> LIBERTADOR O'HIGGINS, CHILE</td><td class="comment updatetimeno" id="upd24" style="text-align:right;">2023-02-08 14:57</td></tr>
#  <tr class="ligne2 normal" id="1220335" onclick="go_details(event,1220335);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220335&amp;f=/FELTREPORTS/122/1220335/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#FFFFFF;">F</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220335">2023-02-08   14:34:37.0</a></b><i class="ago" id="ago25">1hr 50min ago</i></td><td class="tabev1">37.33 </td><td class="tabev2">N  </td><td class="tabev1">37.06 </td><td class="tabev2">E  </td><td class="tabev3">5</td><td class="tabev5" id="magtyp25">ML</td><td class="tabev2">3.0</td><td class="tb_region" id="reg25"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd25" style="text-align:right;">2023-02-08 14:42</td></tr>
#  <tr class="ligne1 normal" id="1220339" onclick="go_details(event,1220339);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220339">2023-02-08   14:33:22.8</a></b><i class="ago" id="ago26">1hr 52min ago</i></td><td class="tabev1">38.11 </td><td class="tabev2">N  </td><td class="tabev1">36.18 </td><td class="tabev2">E  </td><td class="tabev3">3</td><td class="tabev5" id="magtyp26">ML</td><td class="tabev2">2.5</td><td class="tb_region" id="reg26"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd26" style="text-align:right;">2023-02-08 14:47</td></tr>
#  <tr class="ligne2 normal" id="1220338" onclick="go_details(event,1220338);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220338">2023-02-08   14:30:30.6</a></b><i class="ago" id="ago27">1hr 55min ago</i></td><td class="tabev1">15.38 </td><td class="tabev2">N  </td><td class="tabev1">94.48 </td><td class="tabev2">W  </td><td class="tabev3">60</td><td class="tabev5" id="magtyp27">mb</td><td class="tabev2">4.1</td><td class="tb_region" id="reg27"> OFFSHORE OAXACA, MEXICO</td><td class="comment updatetimeno" id="upd27" style="text-align:right;">2023-02-08 14:52</td></tr>
#  <tr class="ligne1 normal" id="1220332" onclick="go_details(event,1220332);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220332">2023-02-08   14:28:48.9</a></b><i class="ago" id="ago28">1hr 56min ago</i></td><td class="tabev1">37.25 </td><td class="tabev2">N  </td><td class="tabev1">36.79 </td><td class="tabev2">E  </td><td class="tabev3">8</td><td class="tabev5" id="magtyp28">ML</td><td class="tabev2">2.9</td><td class="tb_region" id="reg28"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd28" style="text-align:right;">2023-02-08 14:39</td></tr>
#  <tr class="ligne2 info" id="1220321" onclick="go_details(event,1220321);"><td class="tabev0" style="text-align:center;"><a href="https://www.emsc-csem.org/Earthquake/Testimonies/comments.php?id=1220321" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt;69 testimonies&lt;/b&gt; for this earthquake');"><span class="" style="vertical-align:middle;">69</span></a></td><td class="tabev0"></td><td class="tabev0"><span class="intensity" onclick="go_details(event,null,'https://www.emsc-csem.org/Earthquake/popup_intensmap.php?id=1220321&amp;f=/FELTREPORTS/122/1220321/IntensityMap.png');" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','See the &lt;b&gt; Intensity map&lt;/b&gt;');" style="background-color:#66CCFF;">III</span></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220321">2023-02-08   14:20:26.5</a></b><i class="ago" id="ago29">2hr 05min ago</i></td><td class="tabev1">37.99 </td><td class="tabev2">N  </td><td class="tabev1">37.38 </td><td class="tabev2">E  </td><td class="tabev3">3</td><td class="tabev5" id="magtyp29">Mw</td><td class="tabev2">5.1</td><td class="tb_region" id="reg29"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd29" style="text-align:right;">2023-02-08 15:06</td></tr>
#  <tr class="ligne1 normal" id="1220330" onclick="go_details(event,1220330);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220330">2023-02-08   14:17:21.5</a></b><i class="ago" id="ago30">2hr 08min ago</i></td><td class="tabev1">38.10 </td><td class="tabev2">N  </td><td class="tabev1">36.64 </td><td class="tabev2">E  </td><td class="tabev3">7</td><td class="tabev5" id="magtyp30">ML</td><td class="tabev2">2.6</td><td class="tb_region" id="reg30"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd30" style="text-align:right;">2023-02-08 14:35</td></tr>
#  <tr class="ligne2 normal" id="1220326" onclick="go_details(event,1220326);"><td class="tabev0"></td><td class="tabev0"></td><td class="tabev0"></td><td class="tabev6"><b><i style="display:none;">earthquake</i><a href="/Earthquake/earthquake.php?id=1220326">2023-02-08   14:15:04.2</a></b><i class="ago" id="ago31">2hr 10min ago</i></td><td class="tabev1">37.99 </td><td class="tabev2">N  </td><td class="tabev1">36.60 </td><td class="tabev2">E  </td><td class="tabev3">10</td><td class="tabev5" id="magtyp31">ML</td><td class="tabev2">2.7</td><td class="tb_region" id="reg31"> CENTRAL TURKEY</td><td class="comment updatetimeno" id="upd31" style="text-align:right;">2023-02-08 14:29</td></tr>
# ...
#  var tab_tab=new Array( {evid:1220381, ago:"04min ago", comm: "0", pics: "0", intens: "-1", lat:"19.15", lon:"-155.48", depth:"33", mag:"2.0", reg:"ISLAND OF HAWAII, HAWAII",upd:"1675873440"},{evid:1220374, ago:"23min ago", comm: "0", pics: "0", intens: "0", lat:"-4.92", lon:"122.66", depth:"10", mag:"4.1", reg:"SULAWESI, INDONESIA",upd:"1675872600"},{evid:1220380, ago:"24min ago", comm: "0", pics: "0", intens: "-1", lat:"38.15", lon:"38.61", depth:"2", mag:"2.9", reg:"EASTERN TURKEY",upd:"1675873320"},{evid:1220375, ago:"28min ago", comm: "0", pics: "0", intens: "-1", lat:"-5.65", lon:"154.44", depth:"118", mag:"5.0", reg:"BOUGAINVILLE REGION, P.N.G.",upd:"1675873260"},{evid:1220373, ago:"28min ago", comm: "1", pics: "0", intens: "4", lat:"37.32", lon:"37.07", depth:"5", mag:"3.1", reg:"CENTRAL TURKEY",upd:"1675872540"},{evid:1220369, ago:"33min ago", comm: "0", pics: "0", intens: "0", lat:"-2.52", lon:"140.68", depth:"10", mag:"3.9", reg:"NEAR N COAST OF PAPUA, INDONESIA",upd:"1675872300"},{evid:1220365, ago:"35min ago", comm: "11", pics: "0", intens: "3", lat:"37.84", lon:"36.61", depth:"5", mag:"4.3", reg:"CENTRAL TURKEY",upd:"1675872240"},{evid:1220368, ago:"42min ago", comm: "7", pics: "0", intens: "3", lat:"37.05", lon:"36.63", depth:"11", mag:"3.2", reg:"CENTRAL TURKEY",upd:"1675871700"},{evid:1220371, ago:"45min ago", comm: "1", pics: "0", intens: "0", lat:"37.23", lon:"36.96", depth:"17", mag:"2.7", reg:"CENTRAL TURKEY",upd:"1675872420"},{evid:1220363, ago:"52min ago", comm: "0", pics: "0", intens: "0", lat:"-4.85", lon:"39.43", depth:"10", mag:"4.7", reg:"KENYA",upd:"1675872300"},{evid:1220360, ago:"56min ago", comm: "0", pics: "0", intens: "-1", lat:"-42.05", lon:"-73.92", depth:"45", mag:"2.8", reg:"ISLA CHILOE, LOS LAGOS, CHILE",upd:"1675871100"},{evid:1220359, ago:"57min ago", comm: "0", pics: "0", intens: "-1", lat:"38.15", lon:"38.34", depth:"4", mag:"2.9", reg:"EASTERN TURKEY",upd:"1675870740"},{evid:1220364, ago:"59min ago", comm: "0", pics: "0", intens: "-1", lat:"39.02", lon:"40.81", depth:"1", mag:"2.5", reg:"EASTERN TURKEY",upd:"1675871460"},{evid:1220358, ago:"1hr 02min ago", comm: "0", pics: "0", intens: "-1", lat:"37.58", lon:"38.06", depth:"10", mag:"2.8", reg:"EASTERN TURKEY",upd:"1675870200"},{evid:1220355, ago:"1hr 03min ago", comm: "0", pics: "0", intens: "-1", lat:"19.17", lon:"-155.49", depth:"33", mag:"2.7", reg:"ISLAND OF HAWAII, HAWAII",upd:"1675869900"},{evid:1220357, ago:"1hr 04min ago", comm: "0", pics: "0", intens: "-1", lat:"39.14", lon:"40.15", depth:"7", mag:"2.7", reg:"EASTERN TURKEY",upd:"1675870200"},{evid:1220353, ago:"1hr 09min ago", comm: "12", pics: "0", intens: "4", lat:"16.76", lon:"-86.10", depth:"10", mag:"5.5", reg:"OFFSHORE HONDURAS",upd:"1675872060"},{evid:1220354, ago:"1hr 14min ago", comm: "1", pics: "0", intens: "3", lat:"38.12", lon:"38.26", depth:"10", mag:"3.5", reg:"EASTERN TURKEY",upd:"1675869720"},{evid:1220350, ago:"1hr 18min ago", comm: "0", pics: "0", intens: "-1", lat:"38.54", lon:"37.76", depth:"89", mag:"2.5", reg:"CENTRAL TURKEY",upd:"1675869180"},{evid:1220348, ago:"1hr 20min ago", comm: "4", pics: "0", intens: "3", lat:"38.04", lon:"37.04", depth:"4", mag:"4.2", reg:"CENTRAL TURKEY",upd:"1675870260"},{evid:1220349, ago:"1hr 25min ago", comm: "0", pics: "0", intens: "-1", lat:"38.12", lon:"37.24", depth:"24", mag:"2.6", reg:"CENTRAL TURKEY",upd:"1675868880"},{evid:1220346, ago:"1hr 27min ago", comm: "0", pics: "0", intens: "-1", lat:"37.30", lon:"37.05", depth:"6", mag:"2.6", reg:"CENTRAL TURKEY",upd:"1675868520"},{evid:1220345, ago:"1hr 29min ago", comm: "1", pics: "0", intens: "4", lat:"38.11", lon:"38.53", depth:"5", mag:"4.3", reg:"EASTERN TURKEY",upd:"1675869960"},{evid:1220341, ago:"1hr 46min ago", comm: "0", pics: "0", intens: "-1", lat:"38.10", lon:"36.67", depth:"6", mag:"2.8", reg:"CENTRAL TURKEY",upd:"1675867920"},{evid:1220344, ago:"1hr 47min ago", comm: "0", pics: "0", intens: "-1", lat:"-34.53", lon:"-70.37", depth:"131", mag:"2.9", reg:"LI ...
#
#  				var tab_num_alpha=new Array({reg:false,lat:true,lon:true,mag:true,depth:true,upd:true,intens:true,comm:true,pics:true});
#  				//addonload(hide_upd);
#  			</script><span onmouseout="info_b('notshow','','');" onmouseover="info_b('show','This list of events should not be considered as complete. &lt;br /&gt;				Earthquakes with smaller magnitudes are reported for the Euro-Mediterranenan region.&lt;br /&gt;				The reported locations have not been computed by the EMSC and the automatic location can be inaccurate.&lt;br /&gt;				This list is fully dynamic and the information is updated as often as necessary.&lt;br /&gt;				This is particulary the case in the very first hours following an earthquake occurence','Disclaimer');"><a href="/Earthquake/?disclam=yes">Disclaimer</a></span><script> function changeLocation(adress) { window.location.href = adress; }
#  				//function refreshcsem(adress,timeout) { setTimeout('changeLocation("'+adress+'")',timeout*60000); }
#  				//if(/www/i.test(window.location.href)) refreshcsem("/Earthquake/?csemrefresh=true",5);
#  				function rl(timeout) { setTimeout(function() { window.location.reload(); },  timeout*60000); }
#  				rl(5);
#  		</script><p> </p>
#  </br></br></div>,
#  <div id="bann_defile"><span class="markee" id="markee_bann_defile" name="markee_bann_defile">temp</span><span id="bann_disclam" style="display:none;"><a href="/disclaimer.php">Disclaimer</a></span></div>,
#  <div id="quick_access" style="font-size:11px;text-align:center; margin-bottom:5px;">
#  <a href="/Earthquake/?filter=yes"><span class="spriteorig sp_Icon_tools_th" style="margin-right:3px;"></span>Define your criteria</a> to find specific events  -  Quick search:
#  	<a href="/Earthquake/world/M3/"> mag≥3 </a> | <a href="/Earthquake/world/M4/"> mag≥4 </a> | <a href="/Earthquake/world/M5/"> mag≥5 </a>
#  </div>,
#  <div onmouseout="info_b('notshow','','');" onmouseover="info_b('show','Represents the results of information provided by users (Felt earthquake, pictures, testimonies ,...)&lt;br&gt;See an intensity map for more details on the macroseismic intensity scale.','Citizen response');">Citizen<br/>Response</div>,
#  <div onclick="change_tri('im_report');" onmouseout="change_image(this,'out','im_report');" onmouseover="change_image(this,'over','im_report');"><span class="spriteorig sp_ico_list" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Sorted by number of &lt;b&gt;Comments&lt;/b&gt;');"></span><span class="spriteorig sp_s_asc" id="im_report" style="display:none;"></span></div>,
#  <div onclick="change_tri('im_pics');" onmouseout="change_image(this,'out','im_pics');" onmouseover="change_image(this,'over','im_pics');"><span class="spriteorig sp_digikam" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Sorted by number of &lt;b&gt;Pictures&lt;/b&gt;');"></span><span class="spriteorig sp_s_asc" id="im_pics" style="display:none;"></span></div>,
#  <div onclick="change_tri('im_intens');" onmouseout="change_image(this,'out','im_intens');" onmouseover="change_image(this,'over','im_intens');"><span class="spriteorig sp_IntensityMap" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Sorted by &lt;b&gt;Macroseismic Intensity&lt;/b&gt;');"></span><span class="spriteorig sp_s_asc" id="im_intens" style="display:none;"></span></div>,
#  <div style="font-weight:normal;">UTC</div>,
#  <div style="font-weight:normal;">degrees</div>,
#  <div style="font-weight:normal;">degrees</div>,
#  <div style="font-weight: normal">km</div>,
#  <div onclick="change_tri('im_mag');" onmouseout="change_image(this,'out','im_mag');" onmouseover="change_image(this,'over','im_mag');" style="float:left;">Mag <span class="spriteorig sp_s_asc" id="im_mag" style="display:none;"></span></div>,
#  <div id="magplus2" style="float:left;"> <a href="javascript:hide_magni();" id="magplus" style="color:white;">[+]</a></div>,
#  <div onclick="change_tri('im_reg');" onmouseout="change_image(this,'out','im_reg');" onmouseover="change_image(this,'over','im_reg');" style="float:left;">Region name <span class="spriteorig sp_s_asc" id="im_reg" style="display:none;"></span></div>,
#  <div id="upda" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Show last update');"> <a href="javascript:hide_upd();" style="color:white;">[+]</a></div>,
#  <div id="labupd" onclick="change_tri('im_upd');" onmouseout="change_image(this,'out','im_upd');" onmouseover="change_image(this,'over','im_upd');" style="float:left;text-align:right;">Last update <span class="spriteorig sp_s_asc" id="im_upd" style="display:none;"></span></div>,
#  <div id="hideupda" onmouseout="info_b2('notshow','');" onmouseover="info_b2('show','Hide last update');" style="float:left;"><a href="javascript:hide_upd();" style="color:white;">[-]</a></div>,
#  <div class="clearer"></div>,
#  <div id="footer"><!-- ======== PIED DE PAGE ====== -->
#  <div id="footer2">
#  <a href="https://www.emsc-csem.org/faq.php"><b>FAQ</b></a>   <a href="https://www.emsc-csem.org/about/"><b>About EMSC</b></a>
#              <span id="mast"></span><script type="text/javascript">at("webmaster_0_emsc-csem_8_org",true,"","mast","If you have any comments, please contact us");</script>
#  <a href="https://www.emsc-csem.org/sitemap.php"><b>Site Map</b></a>   <a href="https://www.emsc-csem.org/Search/"><b>Search</b></a><br/><br/>
#  <span id="media" style="float:left;width:50%;">Media : <a href="http://twitter.com/lastquake" target="_blank"><span class="spriteorig sp_twitter" title="twitter: @lastquake"></span></a>  <a href="http://twitter.com/EMSC" target="_blank"><span class="spriteorig sp_twitter" title="twitter: @EMSC"></span></a>  <a href="http://www.facebook.com/pages/EMSC-CSEM/207151812690551?sk=wall" target="_blank"><span class="spriteorig sp_facebook" title="facebook: EMSC-CSEM"></span></a>  <a href="https://t.me/LastQuake2" target="_blank"><span style="display:inline-block;background:url(https://static3.emsc.eu/Css/img/telegram-24.png) no-repeat;width:24px;height:24px;" title="Telegram: LastQuake2"></span></a>  <a href="https://t.me/AllQuakes2" target="_blank"><span style="display:inline-block;background:url(https://static3.emsc.eu/Css/img/telegram-24.png) no-repeat;width:24px;height:24px;" title="Telegram: AllQuakes2"></span></a>  <a href="http://www.youtube.com/user/EuroMSC" target="_blank"><span class="spriteorig sp_youtube" title="youtube: EuroMSC"></span></a>
#  </span>Compatibility : <span class="browser spriteorig sp_chrome" title="chrome"></span><span class="browser spriteorig sp_firefox" title="firefox"></span><span class="browser spriteorig sp_ie" title="internet explorer"></span><span class="browser spriteorig sp_opera" title="opera"></span><span class="browser spriteorig sp_safari" title="safari"></span><br/><br/>
#  <center>© 2010 - <b><a href="/policy.php">Privacy</a></b></center>
#  </div></div>,
#  <div id="footer2">
#  <a href="https://www.emsc-csem.org/faq.php"><b>FAQ</b></a>   <a href="https://www.emsc-csem.org/about/"><b>About EMSC</b></a>
#              <span id="mast"></span><script type="text/javascript">at("webmaster_0_emsc-csem_8_org",true,"","mast","If you have any comments, please contact us");</script>
#  <a href="https://www.emsc-csem.org/sitemap.php"><b>Site Map</b></a>   <a href="https://www.emsc-csem.org/Search/"><b>Search</b></a><br/><br/>
#  <span id="media" style="float:left;width:50%;">Media : <a href="http://twitter.com/lastquake" target="_blank"><span class="spriteorig sp_twitter" title="twitter: @lastquake"></span></a>  <a href="http://twitter.com/EMSC" target="_blank"><span class="spriteorig sp_twitter" title="twitter: @EMSC"></span></a>  <a href="http://www.facebook.com/pages/EMSC-CSEM/207151812690551?sk=wall" target="_blank"><span class="spriteorig sp_facebook" title="facebook: EMSC-CSEM"></span></a>  <a href="https://t.me/LastQuake2" target="_blank"><span style="display:inline-block;background:url(https://static3.emsc.eu/Css/img/telegram-24.png) no-repeat;width:24px;height:24px;" title="Telegram: LastQuake2"></span></a>  <a href="https://t.me/AllQuakes2" target="_blank"><span style="display:inline-block;background:url(https://static3.emsc.eu/Css/img/telegram-24.png) no-repeat;width:24px;height:24px;" title="Telegram: AllQuakes2"></span></a>  <a href="http://www.youtube.com/user/EuroMSC" target="_blank"><span class="spriteorig sp_youtube" title="youtube: EuroMSC"></span></a>
#  </span>Compatibility : <span class="browser spriteorig sp_chrome" title="chrome"></span><span class="browser spriteorig sp_firefox" title="firefox"></span><span class="browser spriteorig sp_ie" title="internet explorer"></span><span class="browser spriteorig sp_opera" title="opera"></span><span class="browser spriteorig sp_safari" title="safari"></span><br/><br/>
#  <center>© 2010 - <b><a href="/policy.php">Privacy</a></b></center>
#  </div>,
#  <div class="statcounter" style="display:none;"><a href="http://www.statcounter.com/" target="_blank" title="hit counter"><img alt="hit counter" class="statcounter" src="https://c.statcounter.com/217829/0//1/" style="width:1px;height:1px;"/></a></div>]

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
lan = req.get(url).content
soup = bs(lan, 'html.parser')

# %%
lan = soup.find_all('a',class_='link-box')

# %%
lan[0].text
# Out:
# '\nEnglish\n6\xa0606\xa0000+ articles\n'

# %%
lan[0].text.strip().replace('\n', ' ').replace('\xa0', ' ').replace('+', '')
# Out:
# 'English 6 606 000 articles'

# %%
lan2 = []

for i in range(len(lan)):
    lan2.append(lan[i].text.strip().replace('\n', ' ').replace('\xa0', ' ').replace('+', ''))
lan2
# Out:
# ['English 6 606 000 articles',
#  'Русский 1 887 000 статей',
#  '日本語 1 359 000 記事',
#  'Deutsch 2 764 000 Artikel',
#  'Français 2 488 000 articles',
#  'Español 1 833 000 artículos',
#  'Italiano 1 792 000 voci',
#  '中文 1 331 000 条目 / 條目',
#  'فارسی 947 000 مقاله',
#  'Polski 1 552 000 haseł']

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
dataset = req.get(url).content
soup = bs(dataset, 'html.parser')

# %%
dataset = soup.find_all('a',class_='govuk-link')
dataset[0].text
# Out:
# 'cookies to collect information'

# %%
dataset2 = [dataset[e].text for e in range(len(dataset))]
dataset2 = dataset2[4:]
dataset2
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
